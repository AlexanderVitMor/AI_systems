# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# %%
img = cv.imread('IM/FL1.jpg', cv.IMREAD_GRAYSCALE)

# %%
import numpy as np
import cv2 as cv
img = cv.imread('IM/FL1.jpg')
gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
sift = cv.SIFT_create()
kp = sift.detect(gray,None)
print(len(kp))
img2 = cv.drawKeypoints(img,kp,None,(255,0,0),4)

cv.imshow("SIFT", img2)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# 20852

# %%
kp = sift.detect(img,None)

# %%
img2 = cv.drawKeypoints(img,kp,None,(255,0,0),4)

# %%
plt.imshow(img2),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x1fb17124450>, None)

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread('IM/F1.png', cv.IMREAD_GRAYSCALE) # `<opencv_root>/samples/data/blox.jpg`
# Initiate FAST object with default values
fast = cv.FastFeatureDetector_create()
# find and draw the keypoints
kp = fast.detect(img,None)
img2 = cv.drawKeypoints(img, kp, None, color=(255,0,0))
# Print all default params
print( "Threshold: {}".format(fast.getThreshold()) )
print( "nonmaxSuppression:{}".format(fast.getNonmaxSuppression()) )
print( "neighborhood: {}".format(fast.getType()) )
print( "Total Keypoints with nonmaxSuppression: {}".format(len(kp)) )
plt.imshow(img2), plt.show()
# Out:
# Threshold: 10
# nonmaxSuppression:True
# neighborhood: 2
# Total Keypoints with nonmaxSuppression: 125
# (<matplotlib.image.AxesImage at 0x1fb1add3a10>, None)

# %%
# Disable nonmaxSuppression
fast.setNonmaxSuppression(0)
kp = fast.detect(img, None)
print( "Total Keypoints without nonmaxSuppression: {}".format(len(kp)) )
img3 = cv.drawKeypoints(img, kp, None, color=(255,0,0))
plt.imshow(img3), plt.show()
# Out:
# Total Keypoints without nonmaxSuppression: 516
# (<matplotlib.image.AxesImage at 0x1fb1783a5d0>, None)
